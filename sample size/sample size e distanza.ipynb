# %%
source("sample_size_drift.r")

# %%
d_range=c(0.01,0.05)
sig=0.05
ymax=20000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
# Out:
# Plot with title “alpha = 0.05”

# %%
d_range=c(0.01,0.05)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=20000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
# Out:
# Plot with title “color : towards yellow for decreasing significance
#  alpha =  0.005, 0.01, 0.03, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa 1.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.05)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=20000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
dev.off()
# Out:
# pdf
#   2

# %%
d_range=c(0.01,0.05)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=5000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
# Out:
# Plot with title “color : towards yellow for decreasing significance
#  alpha =  0.005, 0.01, 0.03, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa 2.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.05)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=5000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
dev.off()
# Out:
# pdf
#   2

# %%
d_range=c(0.01,0.1)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=1000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
# Out:
# Plot with title “color : towards yellow for decreasing significance
#  alpha =  0.005, 0.01, 0.03, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa 3.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.1)
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
ymax=1000
plot_alfa_samplesizeVSd(d_range,ymax,sig)
dev.off()
# Out:
# pdf
#   2

# %%
n_range=c(0,500)
dmax=0.5
sig=0.05
plot_alfa_effectsizeVSn(n_range, dmax, sig)
# Out:
# Plot with title “alpha = 0.05”

# %%
n_range=c(0,500)
dmax=0.5
sig=c(0.05,0.01,0.005,0.1)
plot_alfa_effectsizeVSn(n_range, dmax, sig)
# Out:
# Plot with title “color : towards yellow for decreasing significance
#  alpha =  0.005, 0.01, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_effectsize VS samplesize_alfa 1.jpg",   
    width = 700, 
    height = 500) 
n_range=c(0,500)
dmax=0.5
sig=c(0.05,0.01,0.005,0.08)
plot_alfa_effectsizeVSn(n_range, dmax, sig)
dev.off()
# Out:
# pdf
#   2

# %%
n_range=c(0,1000)
dmax=0.1
sig=c(0.05, 0.01,0.03, 0.005, 0.1)
plot_alfa_effectsizeVSn(n_range, dmax, sig)
# Out:
# Plot with title “color : towards yellow for decreasing significance
#  alpha =  0.005, 0.01, 0.03, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_effectsize VS samplesize_alfa 2.jpg",   
    width = 700, 
    height = 500) 
n_range=c(0,1000)
dmax=0.1
sig=c(0.05,0.01,0.005,0.08)
plot_alfa_effectsizeVSn(n_range, dmax, sig)
dev.off()
# Out:
# pdf
#   2

# %%
alfas=c(0.05,0.1,0.001)
distanze=c(0.01,0.02,0.05,0.1)
for (aa in alfas){
    z=z_alfa_mezzi_upper(aa)
    for (x in distanze){
    y=sample_size_alfa(z,x)
    print(paste("alfa = ",as.character(aa), "    dist = ", as.character(x), "    sample size = ",as.character(y)))}}
# Out:
# [1] "alfa =  0.05     dist =  0.01     sample size =  19208"
# [1] "alfa =  0.05     dist =  0.02     sample size =  4802"
# [1] "alfa =  0.05     dist =  0.05     sample size =  769"
# [1] "alfa =  0.05     dist =  0.1     sample size =  193"
# [1] "alfa =  0.1     dist =  0.01     sample size =  13528"
# [1] "alfa =  0.1     dist =  0.02     sample size =  3382"
# [1] "alfa =  0.1     dist =  0.05     sample size =  542"
# [1] "alfa =  0.1     dist =  0.1     sample size =  136"
# [1] "alfa =  0.001     dist =  0.01     sample size =  54138"
# [1] "alfa =  0.001     dist =  0.02     sample size =  13535"
# [1] "alfa =  0.001     dist =  0.05     sample size =  2166"
# [1] "alfa =  0.001     dist =  0.1     sample size =  542"

# %%
alfas=c(0.05,0.1,0.001)
sizes=c(10,250, 500)
for (aa in alfas){
    z=z_alfa_mezzi_upper(aa)
    for (x in sizes){
    y=detected_distance_alfa(z,x)
    print(paste("alfa = ",as.character(aa), "    n = ", as.character(x), "  dist. rilevata min. = ",as.character(round(y,2))))}}
# Out:
# [1] "alfa =  0.05     n =  10   dist. rilevata min. =  0.44"
# [1] "alfa =  0.05     n =  250   dist. rilevata min. =  0.09"
# [1] "alfa =  0.05     n =  500   dist. rilevata min. =  0.06"
# [1] "alfa =  0.1     n =  10   dist. rilevata min. =  0.37"
# [1] "alfa =  0.1     n =  250   dist. rilevata min. =  0.07"
# [1] "alfa =  0.1     n =  500   dist. rilevata min. =  0.05"
# [1] "alfa =  0.001     n =  10   dist. rilevata min. =  0.74"
# [1] "alfa =  0.001     n =  250   dist. rilevata min. =  0.15"
# [1] "alfa =  0.001     n =  500   dist. rilevata min. =  0.1"

# %%
source("sample_size_drift.r")

# %%
d_range=c(0.01,0.05); nmax=40000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6, 0.5
#  blue for power =  0.8”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa_beta 1.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.05); nmax=40000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
dev.off()

# %%
d_range=c(0.01,0.1); nmax=1000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6, 0.5
#  blue for power =  0.8”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa_beta 2.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.1); nmax=1000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
dev.off()
# Out:
# pdf
#   2

# %%
d_range=c(0.01,0.1); nmax=5000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6, 0.5
#  blue for power =  0.8”

# %%
jpeg(file = "plot_samplesize VS effectsize_alfa_beta 3.jpg",   
    width = 700, 
    height = 500) 
d_range=c(0.01,0.1); nmax=5000; alfa=0.05; potenza=c(0.8,0.6,0.5,0.9)
plot_beta_samplesizeVSd(d_range, nmax, alfa, potenza)
dev.off()
# Out:
# pdf
#   2

# %%
potenza=c(0.8,0.9,0.6)
alfa=0.05
n_range=c(0,10000)
dmax=0.1
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6
#  blue for power =  0.8”

# %%
jpeg(file = "plot_effectsize VS samplesize_alfa_beta 1.jpg",   
    width = 700, 
    height = 500) 
potenza=c(0.8,0.9,0.6)
alfa=0.05
n_range=c(0,10000)
dmax=0.1
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
dev.off()
# Out:
# pdf
#   2

# %%
potenza=c(0.8,0.9,0.6)
alfa=0.05
n_range=c(0,5000)
dmax=0.08
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6
#  blue for power =  0.8”

# %%
jpeg(file = "plot_effectsize VS samplesize_alfa_beta 2.jpg",   
    width = 700, 
    height = 500) 
potenza=c(0.8,0.9,0.6)
alfa=0.05
n_range=c(0,5000)
dmax=0.08
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
dev.off()
# Out:
# pdf
#   2

# %%
potenza=c(0.8,0.9,0.6,0.5)
alfa=0.05
n_range=c(0,3000)
dmax=0.1
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
# Out:
# Plot with title “color : towards yellow for decreasing power
#   0.9, 0.8, 0.6, 0.5
#  blue for power =  0.8”

# %%
jpeg(file = "plot_effectsize VS samplesize_alfa_beta 3.jpg",   
    width = 700, 
    height = 500) 
potenza=c(0.8,0.9,0.6)
alfa=0.05
n_range=c(0,3000)
dmax=0.1
plot_beta_effectsizeVSn(n_range, dmax, alfa, potenza)
dev.off()
# Out:
# pdf
#   2

# %%
source("sample_size_drift.r")

# %%
n=100
alfa=c(0.05, 0.1,0.01)
xlimits=c(-0.5,0.5)
plot_power_alfa(n,alfa,xlimits)
# Out:
# [1] 2
# Plot with title “color : towards yellow for decreasing signnificance
#  alpha =  0.01, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_power colore alfa 1.jpg",   
    width = 700, 
    height = 500) 
n=100
alfa=c(0.05, 0.1,0.01)
xlimits=c(-0.5,0.5)
plot_power_alfa(n,alfa,xlimits)
dev.off()
# Out:
# [1] 2
# pdf
#   2

# %%
n=100
alfa=c(0.05, 0.1,0.01)
xlimits=c(0,0.5)
plot_power_alfa(n,alfa,xlimits)
# Out:
# [1] 2
# Plot with title “color : towards yellow for decreasing signnificance
#  alpha =  0.01, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
jpeg(file = "plot_power colore alfa 2.jpg",   
    width = 700, 
    height = 500) 
n=100
alfa=c(0.05, 0.1,0.01)
xlimits=c(0,0.5)
plot_power_alfa(n,alfa,xlimits)
dev.off()
# Out:
# [1] 2
# pdf
#   2

# %%
n=1000
alfa=c(0.05, 0.1,0.01)
xlimits=c(0,0.1)
plot_power_alfa(n,alfa,xlimits)
# Out:
# [1] 2
# Plot with title “color : towards yellow for decreasing signnificance
#  alpha =  0.01, 0.05, 0.1
#  blue for alpha =  0.05”

# %%
samplesize=c(500,100,1000,300)
alfa=0.05
xlimits=c(0,0.5)
plot_power_samplesize(samplesize, alfa, xlimits)
# Out:
# Plot with title “color : towards yellow for decreasing sample size
#  n =  1000, 500, 300, 100
#  blue n =  500”

# %%
jpeg(file = "plot_power colore size 1.jpg",   
    width = 700, 
    height = 500) 
samplesize=c(500,100,1000,300)
alfa=0.05
xlimits=c(0,0.5)
plot_power_samplesize(samplesize, alfa, xlimits)
dev.off()
# Out:
# pdf
#   2

# %%
samplesize=c(500,100,1000,300)
alfa=0.05
xlimits=c(0,0.3)
plot_power_samplesize(samplesize, alfa, xlimits)
# Out:
# Plot with title “color : towards yellow for decreasing sample size
#  n =  1000, 500, 300, 100
#  blue n =  500”
