# %%
import itertools as it
import numpy as np
import matplotlib.pyplot as plt

class Distribution:
    def sample(self):
        raise NotImplementedError

class GaussianMixture(Distribution):
    def __init__(self, mu, sigma, class_, p, n, rng=None):
        if not (len(mu) == len(sigma) == len(class_) == len(p)):
            raise ValueError("All input lists must have the same length.")
        if sum(p) != 1:
            raise ValueError("Probabilities p must sum to 1.")
        
        self.mu = mu
        self.sigma = sigma
        self.class_ = class_
        self.p = p
        self.n = n
        self.rng = rng if rng is not None else np.random.default_rng()

    def sample(self):
        for t in range(self.n):
            i = self.rng.choice(len(self.p), p=self.p)
            mu = self.mu[i]
            sigma = self.sigma[i]
            class_ = self.class_[i]
            x = self.rng.multivariate_normal(mu, np.diag(sigma))
            yield {f'x_{i}': x[i] for i in range(len(x))}, class_

d = GaussianMixture(mu=[[-2, -2], [2, 2]], sigma=[[0.01, 0.2], [0.4, 0.4]],
                    class_=[0, 1], p=[0.5, 0.5], n=1_000)

x_1 = []
x_2 = []
c = []
for x, y in it.islice(d.sample(), 10_000):
    x_1.append(x['x_0'])
    x_2.append(x['x_1'])
    c.append(y)

fig, ax = plt.subplots()
ax.scatter(x_1, x_2, c=c, cmap='bwr', alpha=0.6)
plt.show()

# %%
import numpy as np

class DriftingMixtureStream:
    def __init__(self, mixtures, drift_points, rng=None):
        """
        mixtures: list of GaussianMixture instances (length >= 2)
        drift_points: list of ints or (start, end) tuples, length == len(mixtures) - 1

        Each drift_point defines when to move from mixture[i] to mixture[i+1]:
          - int: abrupt drift at that index
          - (start, end): gradual drift over that interval
        """
        if len(mixtures) < 2:
            raise ValueError("Need at least two mixtures to simulate drift.")
        if len(drift_points) != len(mixtures) - 1:
            raise ValueError("drift_points must have length len(mixtures) - 1.")
        
        self.mixtures = mixtures
        self.drift_points = drift_points
        self.rng = rng if rng is not None else np.random.default_rng()
        self.t = 0
        self.current_idx = 0

    def _interpolate_mixtures(self, mix_a, mix_b, alpha):
        """Return a new GaussianMixture with parameters interpolated between A and B."""
        mu = [(1 - alpha) * np.array(ma) + alpha * np.array(mb)
              for ma, mb in zip(mix_a.mu, mix_b.mu)]
        sigma = [(1 - alpha) * np.array(sa) + alpha * np.array(sb)
                 for sa, sb in zip(mix_a.sigma, mix_b.sigma)]
        p = [(1 - alpha) * pa + alpha * pb for pa, pb in zip(mix_a.p, mix_b.p)]
        # normalize p to sum to 1 (to prevent rounding drift)
        total_p = sum(p)
        p = [pi / total_p for pi in p]
        class_ = mix_a.class_  # assume same class labels
        return GaussianMixture(mu, sigma, class_, p, n=1_000_000, rng=self.rng)

    def sample(self):
        while True:
            if self.current_idx >= len(self.mixtures) - 1:
                # Past last mixture
                yield next(self.mixtures[-1].sample())
                self.t += 1
                continue

            drift = self.drift_points[self.current_idx]

            if isinstance(drift, int):
                # Abrupt drift
                if self.t < drift:
                    yield next(self.mixtures[self.current_idx].sample())
                else:
                    self.current_idx += 1
                    yield next(self.mixtures[self.current_idx].sample())

            else:
                # Gradual drift: (start, end)
                start, end = drift
                if self.t < start:
                    yield next(self.mixtures[self.current_idx].sample())
                elif self.t > end:
                    self.current_idx += 1
                    yield next(self.mixtures[self.current_idx].sample())
                else:
                    alpha = (self.t - start) / (end - start)
                    interpolated_mix = self._interpolate_mixtures(
                        self.mixtures[self.current_idx],
                        self.mixtures[self.current_idx + 1],
                        alpha
                    )
                    yield next(interpolated_mix.sample())

            self.t += 1

# %%
def to_dict(x_array):
    return {f'x_{i}': x_array[i] for i in range(len(x_array))}

def to_array(x_dict):
    return np.array([x_dict[f'x_{i}'] for i in range(len(x_dict))])

def learn_many(model, x_window, y_window):
    for x, y in zip(x_window, y_window):
        x_dict = to_dict(x)
        model.learn_one(x_dict, y)

def accumulate_examples(stream, n, x_window, y_window):
    for x, y in it.islice(stream.sample(), n):
        x_window.append(to_array(x))
        y_window.append(y)

import itertools as it

def accumulate_examples(stream, n, x_window, y_window, keep_fraction=0.0):
    """
    Refill sliding windows from a stream.

    Parameters
    ----------
    stream : iterable
        The data stream yielding (x, y) pairs.
    n : int
        Target window size (number of elements to gather).
    x_window, y_window : deque
        Existing deques for features and labels.
    keep_fraction : float, optional (default=0.0)
        Fraction of the most recent elements to keep before refilling.
        Must be between 0.0 and 1.0.
    """
    # Safety check
    if not (0.0 <= keep_fraction <= 1.0):
        raise ValueError("keep_fraction must be between 0.0 and 1.0")

    # Determine how many elements to retain
    m = int(len(x_window) * keep_fraction)

    # Keep the last m elements
    if m > 0:
        x_recent = list(it.islice(x_window, len(x_window) - m, None))
        y_recent = list(it.islice(y_window, len(y_window) - m, None))
    else:
        x_recent, y_recent = [], []

    # Clear and reinitialize with the recent ones
    x_window.clear()
    y_window.clear()
    x_window.extend(x_recent)
    y_window.extend(y_recent)

    # Fill up the rest from the stream
    n_new = n - len(x_window)
    for x, y in it.islice(stream.sample(), n_new):
        x_window.append(to_array(x))
        y_window.append(y)


def window_accuracy(model, x_window, y_window):
    a = 0
    for x, y in zip(x_window, y_window):
        y_hat = model.predict_one(to_dict(x))
        a += (y_hat == y)
    return a / len(x_window)

class HoeffdingTreeClassifier:
    """Adapter to make a River classifier look like an sklearn estimator."""
    
    def __init__(self, river_model):
        self.model = river_model
        self._estimator_type = "classifier"
        self.classes_ = []
        self.is_fitted_ = False
    
    def fit(self, X, y=None):
        # River models are incremental, so we just stream the data
        self.learn_many(X, y)
        self.is_fitted_ = True
        self.classes_ = np.unique(y)
        return self
    
    def learn_one(self, x, y):
        self.model.learn_one(to_dict(x), y)
        self.is_fitted_ = True
        self.classes_ = np.unique(np.append(self.classes_, y))
        return self
    
    def learn_many(self, x_window, y_window):
        for x, y in zip(x_window, y_window):
            self.learn_one(x, y)
        self.is_fitted_ = True
        return self
    
    def predict(self, X):
        preds = []
        for xi in X:
            y_pred = self.model.predict_one(to_dict(xi))
            preds.append(y_pred)
        return np.array(preds)
    
    def predict_proba(self, X):
        # Not all River models support probabilities — check before using
        probs = []
        for xi in X:
            p = self.model.predict_proba_one(to_dict(xi))
            # fill missing class probabilities with 0
            all_classes = list(self.model.classes)
            probs.append([p.get(c, 0.0) for c in all_classes])
        return np.array(probs)

# %%
import math
import scipy.stats as st

class DriftDetector:
    def detect(self):
        raise NotImplementedError
    
    def reset(self, outliers):
        raise NotImplementedError
    
    def message(self):
        raise NotImplementedError
    
class NoDriftDetector(DriftDetector):
    def reset(self, outliers):
        pass

    def detect(self, outliers):
        return False
    
    def message(self):
        return "No drift detection"
    
class ThresholdDriftDetector(DriftDetector):
    def __init__(self, f=0.1):
        self.f = f

    def reset(self, outliers):
        pass

    def detect(self, outliers):
        outlier_fraction = np.mean(outliers)
        return outlier_fraction > self.f
    
    def message(self):
        return f"Threshold Drift Detection (f={self.f})"

class ZTestDriftDetector(DriftDetector):
    def __init__(self, alpha=0.05):
        self.alpha = alpha
        self.is_built = False

    def reset(self, outliers):
        self.tot_orig = sum(outliers)
        self.n_orig = len(outliers)
        self.is_built = True

    def detect(self, outliers):
        if not self.is_built:
            raise RuntimeError("ZTestDriftDetector has not been reset.")
        tot = sum(outliers)
        n = len(outliers)
        p_outliers = tot / n
        p_orig = self.tot_orig / self.n_orig
        # print(f'p_orig: {p_orig}, p_outliers: {p_outliers}')

        z = st.norm()
        c = abs(p_outliers - p_orig)
        # print(f'Z-Test statistic: {math.sqrt(2*n) * c}, Threshold: {z.ppf(1 - self.alpha / 2)}')
        return c > z.ppf(1 - self.alpha / 2) / math.sqrt(2*n)

    def message(self):
        return rf"Z-test Drift Detection ($\alpha={self.alpha}$)"

# %%
from collections import deque
import itertools as it
from river import tree
import copy

from sklearn.svm import OneClassSVM


def experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction = 0.0):

    orig_model = copy.deepcopy(model)

    x_window = deque(maxlen=n)
    y_window = deque(maxlen=n)
    outlier_window = deque(maxlen=n)
    detected_drifts = []
    accuracy = []

    accumulate_examples(stream, n, x_window, y_window)
    t = n

    learn_many(model, np.array(x_window), np.array(y_window))
    accuracy.append((n, window_accuracy(model, x_window, y_window)))


    occ = OneClassSVM(kernel='rbf', gamma=gamma, nu=nu)
    occ.fit(np.array(x_window))
    for x in x_window:
        curr_x = np.array([x[i] for i in range(len(x))])
        outlier = occ.predict(np.array([curr_x]))[0]
        outlier_window.append(outlier==-1)
    
    detector.reset(outlier_window)

    for x, y in it.islice(stream.sample(), max_t - n):
        t += 1
        y_pred = model.predict_one(x)

        # keep sliding window
        curr_x = to_array(x)

        x_window.append(curr_x)
        y_window.append(y)

        #check for drift using OCC
        outlier = occ.predict(np.array([curr_x]))[0]
        outlier_window.append(outlier==-1)
        
        if detector.detect(outlier_window):
            # print(f'Drift detected at t={t}, with accuracy {accuracy[-1][1]}')
            accumulate_examples(stream, n, x_window, y_window,
                                keep_fraction=keep_fraction)
            
            detected_drifts.append((t, accuracy[-1][1]))
            t += int(n * (1 - keep_fraction))
            # print(f'After accumulation, t={t}')
            a = window_accuracy(model, x_window, y_window)
            # print(f'Post-drift accuracy: {a}')
            accuracy.append((t, a))
            
            # retrain model on current window
            model = copy.deepcopy(orig_model)
            model = model.__class__()
            learn_many(model, np.array(x_window), np.array(y_window))
            # retrain OCC on current window
            occ.fit(np.array(x_window))

            # populate outlier window
            outlier_window.clear()
            for x in x_window:
                curr_x = np.array([x[i] for i in range(len(x))])
                outlier = occ.predict(np.array([curr_x]))[0]
                outlier_window.append(outlier==-1)
            detector.reset(outlier_window)
        else:
            accuracy.append((t, window_accuracy(model, x_window, y_window)))

        if t > max_t:
            break

    # print(x_window)
    return accuracy, detected_drifts

# %%
def generate_figure(ax, accuracy, detected_drifts, stream, detector):
    num_drifts = []
    for a, d in zip(accuracy, detected_drifts):
        num_drifts.append(len(d))
        u, v = zip(*a)
        ax.step(u, v, color='blue', alpha=0.3)
        if d:
            u, v = zip(*d)
            ax.scatter(u, v, color='red', label='Detected Drifts', s=10)

    # for drift in stream.drift_points:
    #     start_drift, end_drift = drift
    #     ax.axvspan(start_drift, end_drift, color='gray', alpha=0.2)
    #     ax.axvline(start_drift, color='gray', linewidth=1.5, alpha=1.0)
    #     ax.axvline(end_drift, color='gray', linewidth=1.5, alpha=1.0)

    message = 'Detected Drifts: '
    message += f'{np.mean(num_drifts):.2f} ± {np.std(num_drifts):.2f}'
    ax.set_title(message)
    ax.set_xlabel(detector.message())

# %%
rng = np.random.default_rng(42)

g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)

# %%
n = 250 # window size
f = 0.1 # outlier fraction threshold
nu = 0.1 # OCC parameter
gamma = 0.5 # OCC parameter
max_t = 8_000 # max number of examples to process

# %% [markdown]
# Codice per calcolare prob retrain

# %%
def upper_q (k,n,p) :
     return(1-st.binom.cdf(k, n, p))


def fixed_perc_p_retrain (n,v, f) :
    k=np.ceil(f*n)
    return(upper_q(k-1,n-1,v)+st.binom.pmf(k-1,n,v)*v)
    # return(upper_q(k,n,v))  #possibile alternative

def n_retrains_idlesteps(retrain_prob, shift_length, stream_length, idle_steps_number=1, verbose=False) :
    mean_step_length=(1-retrain_prob)*idle_steps_number+shift_length*retrain_prob
    mean_steps_mumber=stream_length/mean_step_length
    mean_retr_number=mean_steps_mumber*retrain_prob
    if verbose :
        print(f'p_retrain = {retrain_prob}')
        print(f's = {shift_length}')
        print(f'mean step length = {mean_step_length}')    
        print(f'mean useful steps mumber = {mean_steps_mumber}')  
        print(f'expected retrains number={mean_retr_number}') 
    return(mean_retr_number)




def n_retrains_Wald(retrain_prob, shift_length, stream_length) :
     mean_step_length=retrain_prob*(shift_length-1)+1
     return({'lower bound' : (stream_length*retrain_prob)/mean_step_length,  #the same as n_retrains_*
             'upper bound' : (stream_length+shift_length)*retrain_prob/mean_step_length})

# %% [markdown]
# # Fixed threshold method

# %%
v = 0.1   # outlier detector's (one class classifier) characteristic 

M=8000      # stream size
n=250       # window size
f=0.1       # threshold: fraction of outliers sufficient for triggering a retrain

p_retrain=fixed_perc_p_retrain(n,v,f)


keep=0.1 # as Antoine does      # fraction of window kept in case of retraining
perc_no_overlap=1-keep
s=np.floor(n*perc_no_overlap)   # step length in case of retrain

idle_steps_number=n*f           # rough mean 

expected_retrains=n_retrains_idlesteps(retrain_prob=p_retrain, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number, verbose=True)
# Out:
# p_retrain = 0.530789355814923
# s = 225.0
# mean step length = 131.1578711629846
# mean useful steps mumber = 60.99519555375157
# expected retrains number=32.375600555781055

# %%
p_values = np.linspace(0, 1, num=1000)

nn_retrains=n_retrains_idlesteps(retrain_prob=p_values, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number)

plt.plot(p_values, nn_retrains)
plt.scatter(p_retrain, expected_retrains, color='red')
plt.xlabel("p_retrain")
plt.ylabel("unncecessary retrains")
plt.title("fixed threshold method")
#plt.legend()
#plt.grid(True)
plt.show()

# %%
p_values = np.linspace(0, 1, num=1000)
s_values = [50, 100, 150, 225, 250]
colors = ['yellow', 'orange', 'red', 'black', 'green']

for s, color in zip(s_values, colors):
    n_retrains = n_retrains_idlesteps(retrain_prob=p_values, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number)
    plt.plot(p_values, n_retrains, color=color, label=f"s = {s}")

plt.scatter(p_retrain, expected_retrains, color='black')
plt.xlabel("p_retrain")
plt.ylabel("unncecessary retrains")
plt.title("fixed threshold method")
plt.legend()
#plt.grid(True)
plt.axhline(y=30, color='grey', linestyle='dotted') 
plt.show()

# %%
expected_retrains
# Out:
# np.float64(32.375600555781055)

# %%
model = tree.HoeffdingTreeClassifier()
detector = ThresholdDriftDetector()
seed = 42
stream = g1

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction=0.1)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(242, 342, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ThresholdDriftDetector()


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=0.1)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %%
model = tree.HoeffdingTreeClassifier()
detector = ThresholdDriftDetector()
seed = 42
stream = g1

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction=150/250)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(242, 342, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ThresholdDriftDetector()


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=150/250)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %% [markdown]
# Z-test method

# %%
M=8000
n=250
alfa=0.025

p_retrain=alfa

keep=0.1 # as Antoine does
perc_no_overlap=1-keep
s=np.floor(n*perc_no_overlap)

idle_steps_number=n/2

expected_retrains=n_retrains_idlesteps(retrain_prob=p_retrain, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number, verbose=True)
# Out:
# p_retrain = 0.025
# s = 225.0
# mean step length = 127.5
# mean useful steps mumber = 62.745098039215684
# expected retrains number=1.5686274509803921

# %%
p_values = np.linspace(0, 1, num=1000)

nn_retrains=n_retrains_idlesteps(retrain_prob=p_values, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number)

plt.plot(p_values, nn_retrains)
plt.scatter(p_retrain, expected_retrains, color='red')
plt.xlabel("p_retrain")
plt.ylabel("unncecessary retrains")
plt.title("z-test method ")
#plt.legend()
#plt.grid(True)
plt.show()

# %%
p_values = np.linspace(0, 1, num=1000)
s_values = [50, 100, 150, 225, 250]
colors = ['yellow', 'orange', 'red', 'black', 'green']

for s, color in zip(s_values, colors):
    n_retrains = n_retrains_idlesteps(retrain_prob=p_values, shift_length=s, stream_length=M, 
                     idle_steps_number=idle_steps_number)
    plt.plot(p_values, n_retrains, color=color, label=f"s = {s}")

plt.scatter(p_retrain, expected_retrains, color='black')
plt.xlabel("p_retrain")
plt.ylabel("unncecessary retrains")
plt.title("z-test method ")
plt.legend()
#plt.grid(True)
plt.show()

# %%
expected_retrains
# Out:
# np.float64(1.5686274509803921)

# %%
model = tree.HoeffdingTreeClassifier()
detector = ZTestDriftDetector(alpha=alfa)
seed = 42
stream = g1

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction=0.1)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ZTestDriftDetector(alpha=alfa)


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=0.1)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %%
model = tree.HoeffdingTreeClassifier()
detector = ZTestDriftDetector(alpha=alfa)
seed = 42
stream = g1

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction=150/250)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ZTestDriftDetector(alpha=alfa)


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=150/250)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %%
model = tree.HoeffdingTreeClassifier()
detector = ZTestDriftDetector(alpha=0.6)
seed = 42
stream = g1

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model, keep_fraction=150/250)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ZTestDriftDetector(alpha=0.6)


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=150/250)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %%
n_retrains_idlesteps(retrain_prob=0.6, shift_length=100, stream_length=M, 
                     idle_steps_number=idle_steps_number)
# Out:
# 43.63636363636364

# %%
seeds = np.arange(42, 142, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)

    g1 = GaussianMixture(mu=[[0, -1], [1, 1]], sigma=[[0.01, 0.2], [0.2, 0.01]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    model = tree.HoeffdingTreeClassifier()
    detector = ZTestDriftDetector(alpha=0.6)


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, g1, detector, model, keep_fraction=200/250)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, g1, detector)
plt.show()

# %%
n_retrains_idlesteps(retrain_prob=0.6, shift_length=50, stream_length=M, 
                     idle_steps_number=idle_steps_number)
# Out:
# 60.0

# %% [markdown]
# let's see the two graphs side by side

# %%
fig, ax = plt.subplots(1, 2, sharey=True)

v = 0.1   # outlier detector's (one class classifier) characteristic 

M=8000      # stream size
n=250       # window size
f=0.1       # threshold: fraction of outliers sufficient for triggering a retrain

p_retrain=fixed_perc_p_retrain(n,v,f)


keep=0.1 # as Antoine does      # fraction of window kept in case of retraining
perc_no_overlap=1-keep
s=np.floor(n*perc_no_overlap)   # step length in case of retrain

idle_steps_number=n*f           # rough mean 

expected_retrains=n_retrains_idlesteps(retrain_prob=p_retrain, shift_length=s,
                                       stream_length=M, 
                                       idle_steps_number=idle_steps_number,
                                       verbose=True)


p_values = np.linspace(0, 1, num=1000)
s_values = [50, 100, 150, 225, 250]
colors = ['yellow', 'orange', 'red', 'black', 'green']

for s, color in zip(s_values, colors):
    n_retrains = n_retrains_idlesteps(retrain_prob=p_values,
                                      shift_length=s, stream_length=M, 
                                      idle_steps_number=idle_steps_number)
    ax[0].plot(p_values, n_retrains, color=color, label=f"s = {s}")

ax[0].scatter(p_retrain, expected_retrains, color='black')
ax[0].set_xlabel("p_retrain")
ax[0].set_ylabel("unncecessary retrains")
ax[0].set_title("fixed threshold method")
ax[0].legend()
ax[0].axhline(y=30, color='grey', linestyle='dotted') 



M=8000
n=250
alfa=0.025

p_retrain=alfa

keep=0.1 # as Antoine does
perc_no_overlap=1-keep
s=np.floor(n*perc_no_overlap)

idle_steps_number=n/2

expected_retrains=n_retrains_idlesteps(retrain_prob=p_retrain,
                                       shift_length=s, stream_length=M, 
                                       idle_steps_number=idle_steps_number,
                                       verbose=True)

p_values = np.linspace(0, 1, num=1000)
s_values = [50, 100, 150, 225, 250]
colors = ['yellow', 'orange', 'red', 'black', 'green']

for s, color in zip(s_values, colors):
    n_retrains = n_retrains_idlesteps(retrain_prob=p_values,
                                      shift_length=s, stream_length=M, 
                                      idle_steps_number=idle_steps_number)
    ax[1].plot(p_values, n_retrains, color=color, label=f"s = {s}")

ax[1].scatter(p_retrain, expected_retrains, color='black')
ax[1].set_xlabel("p_retrain")
ax[1].set_ylabel("unncecessary retrains")
ax[1].set_title("z-test method ")
ax[1].legend()

fig.show()
# Out:
# p_retrain = 0.530789355814923
# s = 225.0
# mean step length = 131.1578711629846
# mean useful steps mumber = 60.99519555375157
# expected retrains number=32.375600555781055
# p_retrain = 0.025
# s = 225.0
# mean step length = 127.5
# mean useful steps mumber = 62.745098039215684
# expected retrains number=1.5686274509803921
# /tmp/ipykernel_3201872/1433958258.py:76: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
def bounds(M, p, s):
    return (M * p / (1 + p * (s - 1)), (M + s) * p / (1 + p * (s - 1)))

bounds(8000, 0.025, 250)
# Out:
# (0.11072664359861592, 0.9757785467128028)

# %%
detector = ThresholdDriftDetector(f)
seed = 42
rng = np.random.default_rng(seed)
stream = stream_factory_2_new(seed)
model = tree.HoeffdingTreeClassifier()
detector = ThresholdDriftDetector(f)

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
threshold_accuray = []
threshold_detected_drifts = []
for seed in seeds:
    rng = np.random.default_rng(seed)
    stream = stream_factory_2_new(seed)
    model = tree.HoeffdingTreeClassifier()
    detector = ThresholdDriftDetector(f)


    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
    threshold_accuray.append(accuracy)
    threshold_detected_drifts.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, threshold_accuray, threshold_detected_drifts, stream, detector)
plt.show()

# %%
alpha = 0.025
seed = 42
rng = np.random.default_rng(seed)
stream = stream_factory_2_new(seed)
model = tree.HoeffdingTreeClassifier()
detector = ZTestDriftDetector(alpha)

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
ztest_accuray = []
ztest_detected_drifts = []
for seed in seeds:
    rng = np.random.default_rng(seed)
    stream = stream_factory_2_new(seed)
    model = tree.HoeffdingTreeClassifier()
    detector = ZTestDriftDetector(alpha)

    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
    ztest_accuray.append(accuracy)
    ztest_detected_drifts.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, ztest_accuray, ztest_detected_drifts, stream, detector)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(15, 5))
generate_figure(ax[0], baseline_accuray, detected_drifts_baseline, stream, NoDriftDetector())
generate_figure(ax[1], threshold_accuray, threshold_detected_drifts, stream, ThresholdDriftDetector(f))
generate_figure(ax[2], ztest_accuray, ztest_detected_drifts, stream, ZTestDriftDetector(alpha))
plt.show()

# %%
def stream_factory_3(seed):
    rng = np.random.default_rng(seed)
    g1 = GaussianMixture(mu=[[0, 1], [0, 0]], sigma=[[0.4, 0.4], [0.4, 0.4]],
                        class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    g2 = GaussianMixture(mu=[[0, 0], [1, 1]], sigma=[[0.2, 0.2], [0.2, 0.2]],
                     class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    g3 = GaussianMixture(mu=[[0, 1], [0, 0]], sigma=[[0.4, 0.4], [0.4, 0.4]],
                        class_=[0, 1], p=[0.5, 0.5], n=80_000, rng=rng)
    mixtures=[g1, g2, g3]

    drift_points=[(2_000, 3_000), (5_000, 6_000)]
    stream = DriftingMixtureStream(mixtures=mixtures,
                                drift_points=drift_points,
                                rng=rng)
    return stream

# %%
n = 250 # window size
f = 0.1 # outlier fraction threshold
nu = 0.1 # OCC parameter
gamma = 0.5 # OCC parameter
max_t = 8_000 # max number of examples to process
model = tree.HoeffdingTreeClassifier()

detector = NoDriftDetector()
seed = 42
rng = np.random.default_rng(seed)
stream = stream_factory_3(seed)

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
baseline_accuray = []
detected_drifts_baseline = []
for seed in seeds:
    rng = np.random.default_rng(seed)
    stream = stream_factory_3(seed)

    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
    baseline_accuray.append(accuracy)
    detected_drifts_baseline.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, baseline_accuray, detected_drifts_baseline, stream, detector)
plt.show()

# %%
detector = ThresholdDriftDetector(f)
seed = 42
rng = np.random.default_rng(seed)
stream = stream_factory_3(seed)

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
threshold_accuray = []
threshold_detected_drifts = []
for seed in seeds:
    rng = np.random.default_rng(seed)
    stream = stream_factory_3(seed)

    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
    threshold_accuray.append(accuracy)
    threshold_detected_drifts.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, threshold_accuray, threshold_detected_drifts, stream, detector)
plt.show()

# %%
alpha = 0.025
detector = ZTestDriftDetector(alpha)
seed = 42
rng = np.random.default_rng(seed)
stream = stream_factory_3(seed)

accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
fig, ax = plt.subplots()
generate_figure(ax, [accuracy], [detected_drifts], stream, detector)
plt.show()

# %%
seeds = np.arange(42, 142, 10)
ztest_accuray = []
ztest_detected_drifts = []
for seed in seeds:
    rng = np.random.default_rng(seed)
    stream = stream_factory_3(seed)

    accuracy, detected_drifts = experiment(n, nu, gamma, max_t, stream, detector, model)
    ztest_accuray.append(accuracy)
    ztest_detected_drifts.append(detected_drifts)
fig, ax = plt.subplots()
generate_figure(ax, ztest_accuray, ztest_detected_drifts, stream, detector)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(15, 5))
generate_figure(ax[0], baseline_accuray, detected_drifts_baseline, stream, NoDriftDetector())
generate_figure(ax[1], threshold_accuray, threshold_detected_drifts, stream, ThresholdDriftDetector(f))
generate_figure(ax[2], ztest_accuray, ztest_detected_drifts, stream, ZTestDriftDetector(alpha))
plt.show()

# %% [markdown]
# ## Computation of expected number of unneeded retrains after the
# gradual drift with threshold method

# %%
import scipy.stats as st
import math

f = 0.1
n = 250
T = 8_000
s  = n * 0.9
nu = 0.1

B = st.binom(n, nu)
p = 1 - B.cdf(math.ceil(f*n))

sum([sum([math.comb(i - 1, k) * p**(k+1) * (1-p)**(i - 1 -k) for k in range(0, math.floor((T - i) / (s - 1) -1))]) for i in range(1, T+1)])
# Out:
# np.float64(33.99999999983959)

# %%
import scipy.stats as st
import math

f = 0.1
n = 250
T = 8_000
s  = n * 1
nu = 0.1

B = st.binom(n, nu)
p = 1 - B.cdf(math.ceil(f*n))

sum([sum([math.comb(i - 1, k) * p**(k+1) * (1-p)**(i - 1 -k) for k in range(0, math.floor((T - i) / (s - 1) -1))]) for i in range(1, T+1)])
# Out:
# np.float64(30.000000000262077)

# %%
import scipy.stats as st
import math

def num_exp_retrain(s):

    f = 0.1
    n = 250
    T = 8_000
    # s  = 50
    nu = 0.1

    B = st.binom(n, nu)
    p = 1 - B.cdf(math.ceil(f*n))

    return sum([sum([math.comb(i - 1, k) * p**(k+1) * (1-p)**(i - 1 -k) for k in range(0, math.floor((T - i) / (s - 1) -1))]) for i in range(1, T+1)])

# %%
import matplotlib.pyplot as plt

s_values = list(range(50, 251))
r_values = [num_exp_retrain(s) for s in s_values]
plt.plot(s_values, r_values)
plt.show()

# %%
s_values[-10:]
# Out:
# [241, 242, 243, 244, 245, 246, 247, 248, 249, 250]

# %%
r_values[-10:]
# Out:
# [np.float64(31.830875646700346),
#  np.float64(31.001033096946646),
#  np.float64(31.0),
#  np.float64(31.0),
#  np.float64(31.0),
#  np.float64(30.99999999999559),
#  np.float64(30.999999519065593),
#  np.float64(30.995084786996642),
#  np.float64(30.316121705598604),
#  np.float64(30.000000000262077)]
